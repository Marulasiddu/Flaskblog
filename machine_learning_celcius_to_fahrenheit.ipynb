# %% [markdown]
# <a href="https://colab.research.google.com/github/Marulasiddu/Flaskblog/blob/master/machine_learning_celcius_to_fahrenheit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
import numpy as np

# %%
celcius_q = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit_a = np.array([-40, 14, 32, 46, 59, 72, 104], dtype=float)

for i, c in enumerate(celcius_q):
  print("{} degree Celcius = {} degree Fahrenheit".format(c, fahrenheit_a[i]))
# Out:
# -40.0 degree Celcius = -40.0 degree Fahrenheit
# -10.0 degree Celcius = 14.0 degree Fahrenheit
# 0.0 degree Celcius = 32.0 degree Fahrenheit
# 8.0 degree Celcius = 46.0 degree Fahrenheit
# 15.0 degree Celcius = 59.0 degree Fahrenheit
# 22.0 degree Celcius = 72.0 degree Fahrenheit
# 38.0 degree Celcius = 104.0 degree Fahrenheit

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1])

# %%
model = tf.keras.Sequential([l0])

# %% [markdown]
# **Compile the model, with loss and Optimizer Functions**

# %%
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))

# %%
history = model.fit(celcius_q, fahrenheit_a, epochs=500, verbose=True )
print("Finished training the model!")
# Out:
# Train on 7 samples
# Epoch 1/500
# 7/7 [==============================] - 0s 63ms/sample - loss: 2147.2498
# Epoch 2/500
# 7/7 [==============================] - 0s 611us/sample - loss: 1985.5931
# Epoch 3/500
# 7/7 [==============================] - 0s 479us/sample - loss: 1835.6936
# Epoch 4/500
# 7/7 [==============================] - 0s 419us/sample - loss: 1697.7200
# Epoch 5/500
# 7/7 [==============================] - 0s 217us/sample - loss: 1571.7823
# Epoch 6/500
# 7/7 [==============================] - 0s 248us/sample - loss: 1457.9174
# Epoch 7/500
# 7/7 [==============================] - 0s 250us/sample - loss: 1356.0793
# Epoch 8/500
# 7/7 [==============================] - 0s 262us/sample - loss: 1266.1290
# Epoch 9/500
# 7/7 [==============================] - 0s 207us/sample - loss: 1187.8199
# Epoch 10/500
# 7/7 [==============================] - 0s 209us/sample - loss: 1120.7904
# Epoch 11/500
# ...

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number ')
plt.ylabel('Loss Magnitude')
plt.plot(history.history['loss'])

# %%
print(model.predict([100.0]))
# Out:
# [[215.25134]]

# %%
f = 100*1.8 + 32
print(f)
# Out:
# 212.0

# %%
print("These are the layer variables {}".format(l0.get_weights()))
# Out:
# These are the layer variables [array([[1.8582827]], dtype=float32), array([29.423082], dtype=float32)]

# %%
l0 = tf.keras.layers.Dense(units=4, input_shape=[1])
l1 = tf.keras.layers.Dense(units=4)
l2 = tf.keras.layers.Dense(units=1)
model = tf.keras.Sequential([l0, l1, l2])
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))
model.fit(celcius_q, fahrenheit_a, epochs=500, verbose=False)
print("Finished training the model")
print(model.predict([100.0]))
print("Model predicts that 100 degree Celcius is: {} degree Fahrenheit".format(model.predict([100.0])))
print("These are l0 variables: {}".format(l0.get_weights()))
print("These are l1 variables: {}".format(l1.get_weights()))
print("These are l2 variables: {}".format(l2.get_weights()))
# Out:
# Finished training the model
# [[215.69168]]
# Model predicts that 100 degree Celcius is: [[215.69168]] degree Fahrenheit
# These are l0 variables: [array([[ 0.36980098,  0.4682063 , -0.04343085,  0.34920138]],
#       dtype=float32), array([ 3.0916386,  3.228775 , -3.023613 ,  3.266074 ], dtype=float32)]
# These are l1 variables: [array([[-0.50502455,  0.5310637 , -0.37250122,  0.39533603],
#        [-0.10165275,  0.7748304 ,  0.40047312,  1.1190295 ],
#        [-0.13750888,  0.3003221 , -0.82993835, -1.4137317 ],
#        [ 0.4663818 , -0.46388042, -0.04544696,  0.87323767]],
#       dtype=float32), array([-1.9005963,  3.1760151,  2.1783485,  3.2436442], dtype=float32)]
# These are l2 variables: [array([[-0.26010865],
#        [ 0.3567381 ],
#        [ 0.62846416],
#        [ 1.5777823 ]], dtype=float32), array([3.196001], dtype=float32)]
